# %% [markdown]
# # ReelNexus - Colab Worker
#
# This notebook acts as the GPU processing node for ReelNexus. It polls the Cloudflare Worker API for pending jobs, processes videos using FFmpeg with NVENC hardware acceleration, and uploads the results back to Google Drive.

# %%
# !pip install requests
# !apt-get install -y ffmpeg

# %%
import os
os.environ['API_BASE_URL'] = 'YOUR_CLOUDFLARE_WORKER_URL'
os.environ['COLAB_API_KEY'] = 'YOUR_COLAB_API_KEY'

# !wget -O colab_worker.py https://raw.githubusercontent.com/your-repo/ReelNexus/main/colab/colab_worker.py
# !python colab_worker.py
